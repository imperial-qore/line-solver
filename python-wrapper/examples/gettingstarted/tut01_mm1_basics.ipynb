# %%
from line_solver import *
GlobalConstants.set_verbose(VerboseLevel.STD)

# %%
model = Network('M/M/1')
# Block 1: nodes
source = Source(model, 'mySource')
queue = Queue(model, 'myQueue', SchedStrategy.FCFS)
sink = Sink(model, 'mySink')
# Block 2: classes
jobclass = OpenClass(model, 'myClass')
source.set_arrival(jobclass, Exp(1))
queue.set_service(jobclass, Exp(2))
# Block 3: topology
model.link(Network.serial_routing(source, queue, sink))

# %%
# Block 4: solution
AvgTable = JMT(model, seed=23000, verbose=VerboseLevel.SILENT).avg_table()
# Out:
# SolverJMT command: java -cp /home/gcasale/Dropbox/code/line-dev.git/common/JMT.jar jmt.commandline.Jmt sim /tmp/jmt_5ac1jvqw/model.jsimg
#  Station JobClass   QLen   Util  RespT  ResidT   ArvR   Tput
# mySource  myClass 0.0000 0.0000 0.0000  0.0000 0.0000 1.0000
#  myQueue  myClass 0.9505 0.5028 1.0092  1.0092 1.0119 1.0119

# %%
# select a particular table row
print(tget(AvgTable, queue, jobclass))
# Out:
#    Station JobClass    QLen    Util   RespT  ResidT    ArvR    Tput
# 1  myQueue  myClass  0.9505  0.5028  1.0092  1.0092  1.0119  1.0119

# %%
# select a particular table row by node and class label
print(tget(AvgTable, 'myQueue', 'myClass'))
# Out:
#    Station JobClass    QLen    Util   RespT  ResidT    ArvR    Tput
# 1  myQueue  myClass  0.9505  0.5028  1.0092  1.0092  1.0119  1.0119

# %%
print(AvgTable['RespT'].tolist())
# Out:
# [0.0, 1.0092141100847152]

# %%
print(tget(AvgTable,'myQueue','myClass')['RespT'].tolist())
# Out:
# [1.0092141100847152]
