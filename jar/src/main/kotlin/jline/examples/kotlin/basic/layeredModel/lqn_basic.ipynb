// %%
// Kotlin notebook
import jline.*
import jline.lang.*
import jline.lang.layered.*
import jline.lang.processes.*
import jline.lang.constant.*
import jline.solvers.ln.*

// %%
// Create layered network model
val model = LayeredNetwork("test_LQN_4")

// Create processors with different capacities and scheduling
val P1 = Processor(model, "P1", 2, SchedStrategy.PS)  // 2 cores, processor sharing
val P2 = Processor(model, "P2", 3, SchedStrategy.PS)  // 3 cores, processor sharing

// %%
// Create tasks running on processors
val T1 = Task(model, "T1", 50, SchedStrategy.REF).on(P1).setThinkTime(Exp(1.0 / 2))  // Reference task with 50 users
val T2 = Task(model, "T2", 50, SchedStrategy.FCFS).on(P1).setThinkTime(Exp(1.0 / 3)) // FCFS task with 50 threads
val T3 = Task(model, "T3", 25, SchedStrategy.FCFS).on(P2).setThinkTime(Exp(1.0 / 4)) // FCFS task with 25 threads

// %%
// Create entries (service interfaces) for each task
val E1 = Entry(model, "E1").on(T1)  // Entry point for T1
val E2 = Entry(model, "E2").on(T2)  // Entry point for T2
val E3 = Entry(model, "E3").on(T3)  // Entry point for T3

// %%
// Create activities with service times and call relationships
val A1 = Activity(model, "AS1", Exp(10.0)).on(T1).boundTo(E1).synchCall(E2, 1.0)
val A2 = Activity(model, "AS2", Exp(20.0)).on(T2).boundTo(E2).synchCall(E3, 5.0).repliesTo(E2)
val A3 = Activity(model, "AS3", Exp(50.0)).on(T3).boundTo(E3).repliesTo(E3)

// %%
// Solve the layered queueing network
val avgTable = LN(model).avgTable
println("Average Table:")
avgTable.print()
// Out:
// LN initialization completed. Starting iteration on ensemble models.
// Iter 1.Analyze time: 0.054404s. Update time: 0.000772s. Runtime: 0.054849s.
// Iter 2.Analyze time: 1.772520s. Update time: 0.000319s. Runtime: 1.828741s.
// Iter 3.Analyze time: 1.909744s. Update time: 0.000331s. Runtime: 3.739027s.
// Iter 4.Analyze time: 1.186193s. Update time: 0.000331s. Runtime: 4.925757s.
// Iter 5.Analyze time: 0.988732s. Update time: 0.000314s. Runtime: 5.915002s.
// Iter 6.Analyze time: 1.299742s. Update time: 0.000308s. Runtime: 7.215239s.
// Iter 7.Analyze time: 1.481108s. Update time: 0.000323s. Runtime: 8.696841s.
// Iter 8.Analyze time: 1.211772s. Update time: 0.000302s. Runtime: 9.909122s.
// Iter 9.Analyze time: 1.105110s. Update time: 0.000370s. Runtime: 11.014729s.
// Iter 10.Analyze time: 1.260630s. Update time: 0.000300s. Runtime: 12.275955s.
// Iter 11.Analyze time: 1.349609s. Update time: 0.000304s. Runtime: 13.626021s.
// Iter 12.Analyze time: 1.253592s. Update time: 0.000442s. Runtime: 14.880068s.
// Iter 13.Analyze time: 1.205883s. Update time: 0.000288s. Runtime: 16.086685s.
// Iter 14.Analyze time: 1.273573s. Update time: 0.000294s. Runtime: 17.360707s.
// Iter 15.Analyze time: 1.335006s. Update time: 0.000300s. Runtime: 18.696160s.
// Iter 16.Analyze time: 1.219602s. Update time: 0.000371s. Runtime: 19.916220s.
// Iter 17.Analyze time: 1.186675s. Update time: 0.000293s. Runtime: 21.103451s.
// Iter 18.Analyze time: 1.259805s. Update time: 0.000283s. Runtime: 22.363713s.
// Iter 19.Analyze time: 1.288538s. Update time: 0.000286s. Runtime: 23.652700s.
// Iter 20.Analyze time: 1.217023s. Update time: 0.000289s. Runtime: 24.870155s.
// Iter 21.Analyze time: 1.190340s. Update time: 0.000377s. Runtime: 26.060960s.
// Iter 22.Analyze time: 1.234956s. Update time: 0.000332s. Runtime: 27.296491s.
// Iter 23.Analyze time: 1.252226s. Update time: 0.000288s. Runtime: 28.549202s.
// Iter 24.Analyze time: 1.214808s. Update time: 0.000241s. Runtime: 29.764446s.
// Iter 25.Analyze time: 1.214041s. Update time: 0.000245s. Runtime: 30.978886s.. Started averaging to aid convergence.. Started averaging to aid convergence.. Started averaging to aid convergence.. Started averaging to aid convergence.
// Iter 26.Analyze time: 1.233413s. Update time: 0.000185s. Runtime: 32.213546s.
// Iter 27.Analyze time: 1.245837s. Update time: 0.000202s. Runtime: 33.459931s.
// Iter 28.Analyze time: 0.887563s. Update time: 0.000201s. Runtime: 34.347946s.
// Iter 29.Analyze time: 0.926158s. Update time: 0.000205s. Runtime: 35.274504s.
// Iter 30.Analyze time: 0.997804s. Update time: 0.000355s. Runtime: 36.272693s.
// Iter 31.Analyze time: 1.040792s. Update time: 0.000215s. Runtime: 37.314115s.
// Iter 32.Analyze time: 1.097073s. Update time: 0.000376s. Runtime: 38.411658s.
// Iter 33.Analyze time: 1.151752s. Update time: 0.000170s. Runtime: 39.564037s.
// Iter 34.Analyze time: 1.167410s. Update time: 0.000182s. Runtime: 40.731828s.
// Iter 35.Analyze time: 1.196498s. Update time: 0.000184s. Runtime: 41.928734s.
// Iter 36.Analyze time: 1.216736s. Update time: 0.000187s. Runtime: 43.145841s.
// Iter 37.Analyze time: 1.251761s. Update time: 0.000205s. Runtime: 44.397966s.
// Iter 38.Analyze time: 1.252268s. Update time: 0.000186s. Runtime: 45.650629s.
// Iter 39.Analyze time: 1.369346s. Update time: 0.000201s. Runtime: 47.020369s.
// Iter 40.Analyze time: 1.221118s. Update time: 0.000207s. Runtime: 48.241880s.
// Iter 41.Analyze time: 1.234437s. Update time: 0.000190s. Runtime: 49.476693s.
// Iter 42.Analyze time: 1.214797s. Update time: 0.000228s. Runtime: 50.691837s.
// Iter 43.Analyze time: 1.232543s. Update time: 0.000224s. Runtime: 51.924798s.
// Iter 44.Analyze time: 1.280269s. Update time: 0.000210s. Runtime: 53.205468s.
// Iter 45.Analyze time: 1.224440s. Update time: 0.000192s. Runtime: 54.430284s.
// Iter 46.Analyze time: 1.222416s. Update time: 0.000208s. Runtime: 55.653080s.
// Iter 47.Analyze time: 1.222512s. Update time: 0.000202s. Runtime: 56.875959s.
// Iter 48.Analyze time: 1.236126s. Update time: 0.000226s. Runtime: 58.112462s.
// Iter 49.Analyze time: 1.223960s. Update time: 0.000193s. Runtime: 59.336806s.
// Iter 50.Analyze time: 1.234101s. Update time: 0.000192s. Runtime: 60.571269s.
// Iter 51.Analyze time: 1.226883s. Update time: 0.000315s. Runtime: 61.798513s.
// Iter 52.Analyze time: 1.224743s. Update time: 0.000230s. Runtime: 63.023787s.
// Iter 53.Analyze time: 1.231287s. Update time: 0.000249s. Runtime: 64.255482s.
// Iter 54.Analyze time: 1.227333s. Update time: 0.000221s. Runtime: 65.483247s.
// Iter 55.Analyze time: 1.447353s. Update time: 0.000331s. Runtime: 66.930991sTesting convergence.
//
// Iter 56.Analyze time: 1.306980s. Update time: 0.000206s. Runtime: 68.240091s.
// LN completed in 4 iterations. Running final checks.
//
// Summary: Analyze avg time: 1.218060s. Update avg time: 0.000271s. Total runtime: 69.458875s.
// Average Table:
// Node      	NodeType  	QLen      	Util      	RespT     	ResidT    	ArvR      	Tput
// --------------------------------------------------------------------------------------------
// P1        	Processor 	NaN       	0.99622   	NaN       	NaN       	NaN       	NaN
// P2        	Processor 	NaN       	0.04146   	NaN       	NaN       	NaN       	NaN
// T1        	Task      	23.46245  	0.66426   	NaN       	1.09112   	NaN       	13.28512
// T2        	Task      	8.67733   	0.33197   	NaN       	0.55582   	NaN       	13.27871
// T3        	Task      	0.12049   	0.04146   	NaN       	0.02000   	NaN       	6.21891
// E1        	Entry     	23.46245  	NaN       	1.76607   	NaN       	NaN       	13.28512
// E2        	Entry     	8.67733   	NaN       	0.65348   	NaN       	NaN       	13.27871
// E3        	Entry     	0.12049   	NaN       	0.01938   	NaN       	NaN       	6.21891
// AS1       	Activity  	23.43141  	0.66426   	1.76373   	1.09112   	NaN       	13.28512
// AS2       	Activity  	8.66577   	0.33197   	0.65261   	0.55582   	NaN       	13.27871
// AS3       	Activity  	0.12438   	0.04146   	0.02000   	0.02000   	NaN       	6.21891
// --------------------------------------------------------------------------------------------
