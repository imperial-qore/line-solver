# %% [markdown]
# WARNING: this example is not yet fully functional
# https://github.com/imperial-qore/line-solver/wiki/Getting-started#example-5-modelling-a-re-entrant-line

# %%
from line_solver import *
GlobalConstants.setVerbose(VerboseLevel.STD)

# %%
model = Network('RL')
queue = Queue(model, 'Queue', SchedStrategy.FCFS)
K = 3
N = (1, 0, 0)
jobclass = []
for k in range(K):
    jobclass.append(ClosedClass(model, 'Class' + str(k), N[k], queue))
    queue.setService(jobclass[k], Erlang.fitMeanAndOrder(1+k, 2))
P = model.initRoutingMatrix()
P.set(jobclass[0], jobclass[1], queue, queue, 1.0)
P.set(jobclass[1], jobclass[2], queue, queue, 1.0)
P.set(jobclass[2], jobclass[0], queue, queue, 1.0)
model.link(P)

# %%
ncAvgTable = SolverNC(model).getAvgTable()
# Out:
# isStateValid will ignore some states of station 0, define a unique initial state to address this problem.
# java.lang.NullPointerException
# 	at jline.solvers.nc.NCRunner.run(NCRunner.java:159)
# 	at jline.solvers.nc.SolverNC.runAnalyzer(SolverNC.java:68)
# 	at jline.solvers.NetworkSolver.getAvg(NetworkSolver.java:186)
# 	at jline.solvers.NetworkSolver.getAvgTable(NetworkSolver.java:493)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File NetworkSolver.java:505, in jline.solvers.NetworkSolver.getAvgTable()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ncAvgTable = SolverNC(model).getAvgTable()
#
# File ~/Dropbox/code/line-solver.git/python/line_solver/solvers.py:43, in Solver.getAvgTable(self)
#      42 def getAvgTable(self):
# ---> 43     table = self.obj.getAvgTable()
#      44     # convert to NumPy
#      46     QLen = np.array(list(table.getQLen()))
#
# java.lang.NullPointerException: java.lang.NullPointerException

# %%
ncAvgSysTable = SolverNC(model).getAvgSysTable()

# %%
jobclass[0].completes = False
jobclass[1].completes = False
ncAvgSysTable2 = SolverNC(model).getAvgSysTable()
