# %% [markdown]
# WARNING: this example is not yet fully functional
# https://github.com/imperial-qore/line-solver/wiki/Getting-started#example-4-round-robin-load-balancing

# %%
from line_solver import *
GlobalConstants.setVerbose(VerboseLevel.STD)

# %%
model = Network('RRLB')
source = Source(model, 'Source')
lb = Router(model, 'LB')
queue1 = Queue(model, 'Queue1', SchedStrategy.PS)
queue2 = Queue(model, 'Queue2', SchedStrategy.PS)
sink = Sink(model, 'Sink')
oclass = OpenClass(model, 'Class1')
source.setArrival(oclass, Exp(1))
queue1.setService(oclass, Exp(2))
queue2.setService(oclass, Exp(2))

# %%
model.addLinks([[source, lb], 
               [lb, queue1],  
               [lb, queue2],
               [queue1, sink],
               [queue2, sink]])
lb.setRouting(oclass, RoutingStrategy.RAND)
jmtAvgTable = SolverJMT(model,'seed',23000).getAvgTable()
# Out:
# JMT Model: /tmp/workspace/jsim/4750348343323837298/model.jsim
# JMT Analysis completed. Runtime: 0.924 seconds
#   Station JobClass      QLen      Util     RespT    ResidT      ArvR      Tput
# 0  Source   Class1  0.000000  0.000000  0.000000  0.000000  1.013486  1.013486
# 1  Queue1   Class1  0.316119  0.246825  0.654111  0.327056  0.500997  0.500997
# 2  Queue2   Class1  0.334030  0.250757  0.684064  0.342032  0.504135  0.504135

# %%
# TODO: buggy result, throws an exception
#model.reset()
#lb.setRouting(oclass, RoutingStrategy.RROBIN)
#jmtAvgTableRR = SolverJMT(model,'seed',23000).getAvgTable()
#print(jmtAvgTableRR)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File Network.java:2957, in jline.lang.Network.reset()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# Cell In[4], line 2
#       1 # TODO: buggy result, throws an exception
# ----> 2 model.reset()
#       3 lb.setRouting(oclass, RoutingStrategy.RROBIN)
#       4 jmtAvgTableRR = SolverJMT(model,'seed',23000).getAvgTable()
#
# File ~/Dropbox/code/line-solver.git/python/line_solver/lang.py:204, in Network.reset(self, hard)
#     203 def reset(self, hard=True):
# --> 204     self.obj.reset(hard)
#
# java.lang.NullPointerException: java.lang.NullPointerException
