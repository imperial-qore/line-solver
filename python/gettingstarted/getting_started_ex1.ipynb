# %% [markdown]
# https://github.com/imperial-qore/line-solver/wiki/Getting-started#example-1-a-mm1-queue

# %%
from line_solver import *

# %%
model = Network('M/M/1')
# Block 1: nodes
source = Source(model, 'mySource')
queue = Queue(model, 'myQueue', SchedStrategy.FCFS)
sink = Sink(model, 'mySink')
# Block 2: classes
oclass = OpenClass(model, 'myClass')
source.setArrival(oclass, Exp(1))
queue.setService(oclass, Exp(2))
# Block 3: topology
model.link(Network.serialRouting(source, queue, sink))

# %%
# Block 4: solution
AvgTable = SolverJMT(model, 'seed', 23000, 'samples', 10000).getAvgTable()
# Out:
# JMT Model: /tmp/workspace/jsim/13862844591665138051/model.jsim
# JMT Command: java -cp /home/gcasale/Dropbox/code/line-solver.git/python/line_solver/JMT.jar jmt.commandline.Jmt sim /tmp/workspace/jsim/13862844591665138051/model.jsim -seed 23000 --illegal-access=permit
# JMT Analysis completed. Runtime: 0.77 seconds

# %%
# select a particular table row
ARow = tget(AvgTable, queue, oclass)
print(ARow, end='\n\n')
# Out:
#    Station JobClass      QLen     Util     RespT    ResidT      Tput
# 1  myQueue  myClass  0.955501  0.48736  0.954293  0.954293  0.999868

# %%
# select a particular table row by node and class label
ARow = tget(AvgTable, 'myQueue', 'myClass')
print(ARow)
# Out:
#    Station JobClass      QLen     Util     RespT    ResidT      Tput
# 1  myQueue  myClass  0.955501  0.48736  0.954293  0.954293  0.999868
