# %% [markdown]
# https://github.com/imperial-qore/line-solver/wiki/Getting-started#example-1-a-mm1-queue

# %%
from line_solver import *
GlobalConstants.setVerbose(VerboseLevel.STD)

# %%
model = Network('M/M/1')
# Block 1: nodes
source = Source(model, 'mySource')
queue = Queue(model, 'myQueue', SchedStrategy.FCFS)
sink = Sink(model, 'mySink')
# Block 2: classes
oclass = OpenClass(model, 'myClass')
source.setArrival(oclass, Exp(1))
queue.setService(oclass, Exp(2))
# Block 3: topology
model.link(Network.serialRouting(source, queue, sink))

# %%
# Block 4: solution
AvgTable = SolverJMT(model, 'seed', 23000, 'samples', 10000).getAvgTable()
# Out:
# java.lang.IndexOutOfBoundsException: Index 1 out of bounds for length 0
# 	at java.base/jdk.internal.util.Preconditions.outOfBounds(Preconditions.java:64)
# 	at java.base/jdk.internal.util.Preconditions.outOfBoundsCheckIndex(Preconditions.java:70)
# 	at java.base/jdk.internal.util.Preconditions.checkIndex(Preconditions.java:248)
# 	at java.base/java.util.Objects.checkIndex(Objects.java:372)
# 	at java.base/java.util.ArrayList.get(ArrayList.java:459)
# 	at jline.solvers.jmt.SolverJMT.writeJSIM(SolverJMT.java:2867)
# 	at jline.solvers.jmt.SolverJMT.writeJSIM(SolverJMT.java:2912)
# 	at jline.solvers.jmt.SolverJMT.runAnalyzer(SolverJMT.java:3682)
# 	at jline.solvers.NetworkSolver.getAvg(NetworkSolver.java:186)
# 	at jline.solvers.NetworkSolver.getAvgTable(NetworkSolver.java:445)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File NetworkSolver.java:457, in jline.solvers.NetworkSolver.getAvgTable()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Block 4: solution
# ----> 2 AvgTable = SolverJMT(model, 'seed', 23000, 'samples', 10000).getAvgTable()
#
# File ~/Dropbox/code/line-solver.git/python/line_solver/solvers.py:43, in Solver.getAvgTable(self)
#      42 def getAvgTable(self):
# ---> 43     table = self.obj.getAvgTable()
#      44     # convert to NumPy
#      46     QLen = np.array(list(table.getQLen()))
#
# java.lang.NullPointerException: java.lang.NullPointerException

# %%
# select a particular table row
ARow = tget(AvgTable, queue, oclass)

# %%
# select a particular table row by node and class label
ARow = tget(AvgTable, 'myQueue', 'myClass')
