# %% [markdown]
# https://github.com/imperial-qore/line-solver/wiki/Getting-started#example-1-a-mm1-queue

# %%
from line_solver import *

# %%
model = Network('M/M/1')
# Block 1: nodes
source = Source(model, 'mySource')
queue = Queue(model, 'myQueue', SchedStrategy.FCFS)
sink = Sink(model, 'mySink')
# Block 2: classes
oclass = OpenClass(model, 'myClass')
source.setArrival(oclass, Exp(1))
queue.setService(oclass, Exp(2))
# Block 3: topology
model.link(Network.serialRouting(source, queue, sink))

# %%
# Block 4: solution
AvgTable = SolverJMT(model, 'seed', 23000, 'samples', 10000).getAvgTable()
# Out:
# JMT Model: /tmp/workspace/jsim/2387593003057859357/model.jsim
# JMT Analysis completed. Runtime: 0.759 seconds

# %%
# select a particular table row
ARow = tget(AvgTable, queue, oclass)
print(ARow, end='\n\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # select a particular table row
# ----> 2 ARow = tget(AvgTable, queue, oclass)
#       3 print(ARow, end='\n\n')
#
# File ~/Dropbox/code/line-solver.git/python/line_solver/utils.py:20, in tget(table, *argv)
#      18     jobclass = argv[1]
#      19     results = table.loc[(table["Station"] == station) & (table["JobClass"] == jobclass)]
# ---> 20 elif isinstance(argv[0], gallery.lang.JobClass):
#      21     station = argv[0].obj.getName()
#      22     jobclass = argv[1].obj.getName()
#
# NameError: name 'gallery' is not defined

# %%
# select a particular table row by node and class label
ARow = tget(AvgTable, 'myQueue', 'myClass')
print(ARow)
