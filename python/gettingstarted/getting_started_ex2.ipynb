# %% [markdown]
# WARNING: this example is not yet fully functional
# https://github.com/imperial-qore/line-solver/wiki/Getting-started#example-2-a-multiclass-mg1-queue

# %%
from line_solver import *
GlobalConstants.setVerbose(VerboseLevel.STD)

# %%
model = Network('M/G/1')
source = Source(model, 'Source')
queue = Queue(model, 'Queue', SchedStrategy.FCFS)
sink = Sink(model, 'Sink')
jobclass1 = OpenClass(model, 'Class1')
jobclass2 = OpenClass(model, 'Class2')
source.setArrival(jobclass1, Exp(0.5))
source.setArrival(jobclass2, Exp(0.5))
queue.setService(jobclass1, Erlang.fitMeanAndSCV(1, 1 / 3))
queue.setService(jobclass2, Replayer.fitAPH("example_trace.txt"))

# %%
P = model.initRoutingMatrix()
P.set(jobclass1, jobclass1, Network.serialRouting(source,queue,sink))
P.set(jobclass2, jobclass2, Network.serialRouting(source,queue,sink))
model.link(P)

# %%
jmtAvgTable = SolverJMT(model,'seed',23000).getAvgTable()
# Out:
# JMT Model: /tmp/workspace/jsim/7955719514502154869/model.jsim
# JMT Analysis completed. Runtime: 1.06 seconds
#   Station JobClass      QLen      Util     RespT    ResidT      Tput
# 0  Source   Class1  0.000000  0.000000  0.000000  0.000000  0.501685
# 1  Source   Class2  0.000000  0.000000  0.000000  0.000000  0.506538
# 2   Queue   Class1  0.880661  0.494749  1.737321  1.737321  0.506679
# 3   Queue   Class2  0.438433  0.053432  0.817414  0.817414  0.507503

# %%
#ctmcAvgTable2 = SolverCTMC(model,'cutoff',2,'verbose',True).getAvgTable()
#ctmcAvgTable4 = SolverCTMC(model,'cutoff',4,'verbose',True).getAvgTable()

# %%
mamAvgTable = SolverMAM(model).getAvgTable()
# Out:
#   Station JobClass      QLen      Util     RespT    ResidT  Tput
# 0  Source   Class1  0.000000  0.000000  0.000000  0.000000   0.5
# 1  Source   Class2  0.000000  0.000000  0.000000  0.000000   0.5
# 2   Queue   Class1  0.876460  0.500000  1.752920  1.752920   0.5
# 3   Queue   Class2  0.426996  0.050536  0.853991  0.853991   0.5
