# %%
from line_solver import *

if __name__ == "__main__":
    model = Network("M/M/1 model")
    source = Source(model, "mySource")
    queue = Queue(model, "myQueue", SchedStrategy.FCFS)
    sink = Sink(model, "mySink")

    # An M/M/1 queue with arrival rate 0.5 and service rate 1.0
    openclass = OpenClass(model, "Class1")
    source.setArrival(openclass, Exp(0.5))
    queue.setService(openclass, Exp(1.0))

    model.addLink(source, queue)
    model.addLink(queue, sink)

    solver = SolverJMT(model)
    table = solver.getAvgTable()  # pandas.DataFrame
    print(table)
# Out:
# JMT Model: /tmp/workspace/jsim/3136614956632430622/model.jsim
# JMT Command: java -cp /home/gcasale/Dropbox/code/line-solver.git/python/line_solver/JMT.jar jmt.commandline.Jmt sim /tmp/workspace/jsim/3136614956632430622/model.jsim -seed 573396 --illegal-access=permit
# JMT Analysis completed. Runtime: 0.767 seconds
#     Station JobClass      QLen     Util     RespT    ResidT      Tput
# 0  mySource   Class1  0.000000  0.00000  0.000000  0.000000  0.491565
# 1   myQueue   Class1  1.015818  0.49306  1.953463  1.953463  0.490550
