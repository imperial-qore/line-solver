# %%
import time
from line_solver import *
GlobalConstants.setVerbose(VerboseLevel.STD)

# %%
t = time.time()
model = Network('model')

source = Source(model,'Source')
queue1 = Queue(model,'Queue1',SchedStrategy.FCFS)
queue2 = Queue(model,'Queue2',SchedStrategy.FCFS)
fork = Fork(model,'Fork')
join = Join(model,'Join', fork)
sink = Sink(model,'Sink')

jobclass1 = OpenClass(model, 'class1')

source.setArrival(jobclass1, Exp(0.05))
queue1.setService(jobclass1, Exp(1.0))
queue2.setService(jobclass1, Exp(2.0))

P = model.initRoutingMatrix()
P.set(jobclass1, jobclass1, source, fork, 1.0)
P.set(jobclass1, jobclass1, fork, queue1, 1.0)
P.set(jobclass1, jobclass1, fork, queue2, 1.0)
P.set(jobclass1, jobclass1, queue1, join, 1.0)
P.set(jobclass1, jobclass1, queue2, join, 1.0)
P.set(jobclass1, jobclass1, join, sink, 1.0)

model.link(P)

# %%
solver = np.array([], dtype=object)
#solver = np.append(solver, SolverJMT(model,'seed',23000,'verbose',False,'keep',True))
solver = np.append(solver, SolverMVA(model))

AvgTable = np.empty(len(solver), dtype=object)
for s in range(len(solver)):
    print(f'\nSOLVER: {solver[s].getName()}')
    AvgTable[s] = solver[s].getAvgTable()
    
print(time.time()-t)
# Out:
# SOLVER: SolverMVA
# java.lang.IllegalArgumentException: Outside of matrix bounds
# 	at org.ejml.data.DMatrixSparseCSC.set(DMatrixSparseCSC.java:232)
# 	at jline.util.Matrix.set(Matrix.java:328)
# 	at jline.lang.Network.getRoutingMatrix(Network.java:2028)
# 	at jline.lang.Network.refreshRoutingMatrix(Network.java:1825)
# 	at jline.lang.Network.refreshChains(Network.java:1758)
# 	at jline.lang.Network.refreshStruct(Network.java:811)
# 	at jline.lang.Network.getStruct(Network.java:681)
# 	at jline.solvers.mva.MVARunner.run(MVARunner.java:84)
# 	at jline.solvers.mva.SolverMVA.runAnalyzer(SolverMVA.java:44)
# 	at jline.solvers.NetworkSolver.getAvg(NetworkSolver.java:168)
# 	at jline.solvers.NetworkSolver.getAvgTable(NetworkSolver.java:419)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File NetworkSolver.java:425, in jline.solvers.NetworkSolver.getAvgTable()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# Cell In[3], line 8
#       6 for s in range(len(solver)):
#       7     print(f'\nSOLVER: {solver[s].getName()}')
# ----> 8     AvgTable[s] = solver[s].getAvgTable()
#      10 print(time.time()-t)
#
# File ~/Dropbox/code/line-solver.git/python/line_solver/solvers.py:43, in Solver.getAvgTable(self)
#      42 def getAvgTable(self):
# ---> 43     table = self.obj.getAvgTable()
#      44     # convert to NumPy
#      46     QLen = np.array(list(table.getQLen()))
#
# java.lang.NullPointerException: java.lang.NullPointerException
